# %%
import tensorflow as tf

# Load the model (saved with model.save("path"))
model = tf.keras.models.load_model("pen_to_pixel.keras")   # For HDF5 format (.h5)    # For SavedModel format (folder)

# Check the model summary
model.summary()

# Example: make a prediction
import numpy as np
sample_input = np.random.rand(1, 64, 64, 1)  # shape must match your model input
prediction = model.predict(sample_input)

print("Prediction:", prediction)
# Out:
# 2025-09-06 10:35:47.916944: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-06 10:35:48.237523: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-09-06 10:35:49.385172: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.datasets import mnist

# Load model
model = tf.keras.models.load_model("pen_to_pixel.keras")
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# Load MNIST
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize
x_test = x_test.astype("float32") / 255.0

# Resize to 64x64 and add channel dim
x_test_resized = tf.image.resize(tf.expand_dims(x_test, -1), [64, 64])  # (N, 64, 64, 1)

# Evaluate
loss, acc = model.evaluate(x_test_resized, y_test, verbose=0)
print(f"MNIST Test Accuracy: {acc:.4f}")
# Out:
# 2025-09-06 10:35:55.585725: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_151', 60 bytes spill stores, 60 bytes spill loads
# MNIST Test Accuracy: 0.1034

# %%
x_test_resized = tf.image.resize(tf.expand_dims(x_test, -1), [64, 64])
loss, acc = model.evaluate(x_test_resized, y_test, verbose=0)
print(f"MNIST Test Accuracy: {acc:.4f}")
# Out:
# MNIST Test Accuracy: 0.1034

# %%
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 64, 64, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 64, 64, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import os
import string

# =========================
# Load your trained model
# =========================
model = keras.models.load_model("pen_to_pixel_colab.keras")   # change path if needed

# =========================
# Define class labels (62 classes: 0-9, A-Z, a-z)
# =========================
digits = list(string.digits)           # ['0','1',...,'9']
uppercase = list(string.ascii_uppercase)  # ['A','B',...,'Z']
lowercase = list(string.ascii_lowercase)  # ['a','b',...,'z']
class_labels = digits + uppercase + lowercase  # total 62 classes

# =========================
# Function to test single grayscale image
# =========================
def predict_single_image(img_path):
    if not os.path.exists(img_path):
        raise FileNotFoundError(f"File not found: {img_path}")
    
    # Load image as GRAYSCALE and resize to 128x128
    img = image.load_img(img_path, target_size=(64, 64), color_mode="grayscale")
    
    # Convert to array (128,128,1)
    img_array = image.img_to_array(img)
    
    # Normalize (0–1)
    img_array = img_array / 255.0
    
    # Add batch dimension → shape (1,128,128,1)
    img_array = np.expand_dims(img_array, axis=0)
    
    # Make prediction
    prediction = model.predict(img_array)
    
    # Plot the grayscale image
    plt.imshow(img_array[0].squeeze(), cmap="gray")
    plt.axis("off")
    plt.title("Resized to 128x128 (Grayscale)")
    plt.show()
    
    # Get predicted class index
    predicted_class = np.argmax(prediction, axis=1)[0]
    
    # Map to label
    predicted_label = class_labels[predicted_class]
    
    print("Raw prediction:", prediction)
    print("Predicted class index:", predicted_class)
    print("Predicted label:", predicted_label)
    
    return predicted_label

# =========================
# Example usage
# =========================
img_path = "/home/patil/Pictures/q.jpeg"   # put your local image path
predicted = predict_single_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# Raw prediction: [[6.7864394e-01 2.5839820e-03 6.8651751e-04 6.6975685e-05 3.0411577e-03
#   1.1694646e-03 2.3175347e-04 4.7773359e-04 4.7393995e-03 9.4860019e-03
#   1.6750344e-05 2.1847543e-05 4.8904034e-04 5.1313862e-03 2.1029472e-04
#   7.5126263e-05 1.1221008e-05 2.1683077e-06 1.3980503e-02 7.0561040e-03
#   1.4218102e-06 2.9329399e-03 5.5497377e-03 4.5490381e-04 1.3121943e-01
#   6.0133776e-04 9.4792229e-04 5.3566112e-08 1.9106547e-03 4.6630368e-05
#   1.0004535e-01 3.5701520e-03 4.0414630e-04 3.6361043e-06 4.6943598e-03
#   6.6767307e-06 1.1814006e-03 5.2413834e-05 7.0105032e-03 5.9385207e-03
#   5.4173066e-05 2.3564531e-03 9.9924895e-09 1.4397245e-03 2.5303036e-04
#   3.8163655e-04 8.2136242e-04]]
# Predicted class index: 0
# Predicted label: 0

# %%
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# Raw prediction: [[2.56551001e-02 1.87222034e-01 1.76385492e-02 6.00970350e-03
#   1.18462555e-02 1.01585081e-02 1.40868989e-03 4.28777561e-03
#   1.08509716e-02 2.02571712e-02 1.45310722e-03 5.59745822e-04
#   2.28763744e-03 5.74125722e-03 2.02536257e-03 1.03130564e-02
#   8.14085244e-04 1.50848991e-05 1.05344236e-01 3.24322134e-02
#   3.55567463e-04 1.00214876e-01 8.37255968e-04 3.00027407e-03
#   4.59186174e-02 3.70399142e-03 3.39640945e-04 2.51599908e-04
#   3.60525846e-02 5.67578524e-02 2.10794173e-02 3.91753018e-03
#   9.11834824e-04 2.35823216e-03 6.35387097e-03 1.51687732e-03
#   2.34683845e-02 4.89325216e-03 7.80188218e-02 1.50310742e-02
#   3.79038462e-03 1.37253869e-02 9.07779671e-03 2.05435343e-02
#   1.35355128e-03 5.07779680e-02 3.94292623e-02]]
# Predicted class index: 1
# Predicted label: 1

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import os
import string

# =========================
# Load your trained model
# =========================
model = keras.models.load_model("pen_to_pixel_colab.keras")   # change path if needed

# =========================
# Define class labels (62 classes: 0-9, A-Z, a-z)
# =========================
digits = list(string.digits)           
uppercase = list(string.ascii_uppercase)  
lowercase = list(string.ascii_lowercase)  
class_labels = digits + uppercase + lowercase  

# =========================
# Function to test single grayscale image
# =========================
def predict_single_image(img_path):
    if not os.path.exists(img_path):
        raise FileNotFoundError(f"File not found: {img_path}")
    
    # 🔹 Resize to 128x128 (NOT 64x64) and grayscale
    img = image.load_img(img_path, target_size=(64, 64), color_mode="grayscale")
    
    # Convert to array (128,128,1)
    img_array = image.img_to_array(img)
    
    # Normalize (0–1)
    img_array = img_array / 255.0
    
    # Invert → background black, text white
    img_array = 1.0 - img_array
    
    # Add batch dimension → shape (1,128,128,1)
    img_array = np.expand_dims(img_array, axis=0)
    
    # Make prediction
    prediction = model.predict(img_array)
    
    # Plot the input
    plt.imshow(img_array[0].squeeze(), cmap="gray")
    plt.axis("off")
    plt.title("Input (128x128, Inverted)")
    plt.show()
    
    # Get predicted class index
    predicted_class = np.argmax(prediction, axis=1)[0]
    predicted_label = class_labels[predicted_class]
    
    # Print results
    print("Predicted class index:", predicted_class)
    print("Predicted label:", predicted_label)
    
    # Top-5 predictions
    top5 = np.argsort(prediction[0])[-5:][::-1]
    print("\nTop 5 predictions:")
    for i in top5:
        print(f"  {i}: {class_labels[i]} ({prediction[0][i]:.4f})")
    
    return predicted_label

# =========================
# Example usage
# =========================
img_path = "/home/patil/Pictures/n.jpeg"   # your test image
predicted = predict_single_image(img_path)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e15b6bdbe20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# Predicted class index: 1
# Predicted label: 1
#
# Top 5 predictions:
#   1: 1 (0.1872)
#   18: I (0.1053)
#   21: L (0.1002)
#   38: c (0.0780)
#   29: T (0.0568)
